# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

ACCOUNT_ID = os.environ.get("CLOUDFLARE_ACCOUNT_ID")
AUTH_TOKEN = os.environ.get("CLOUDFLARE_AUTH_TOKEN")

prompt = "Tell me all about PEP-8"
response = requests.post(
  f"https://api.cloudflare.com/client/v4/accounts/{ACCOUNT_ID}/ai/v1/responses",
    headers={"Authorization": f"Bearer {AUTH_TOKEN}"},
    json={
      "model": "@cf/openai/gpt-oss-120b",
      "input": "Tell me all about PEP-8"
    }
)
result = response.json()
print(result)
# Out:
# {'id': 'id-1761406663928', 'created_at': 1761406663, 'instructions': None, 'metadata': None, 'model': '@cf/openai/gpt-oss-120b', 'object': 'response', 'output': [{'id': 'rs_0d04ba6d4387424aa875f5f4c5f2b4b6', 'content': [{'text': 'The user asks: "Tell me all about PEP-8". They want a comprehensive overview of PEP 8, the Python style guide. We should provide thorough information: purpose, history, key guidelines (naming conventions, indentation, line length, whitespace, imports, comments, docstrings, programming recommendations, etc.), examples. Maybe mention tools like flake8, pycodestyle, black. Also mention changes over time, references. The response should be safe, no disallowed content. Provide detailed answer.', 'type': 'reasoning_text'}], 'summary': [], 'type': 'reasoning', 'encrypted_content': None, 'status': None}, {'id': 'msg_d0e85f1b3bc34ae094f258112c6bc90d', 'content': [{'annotations': [], 'text': '## PEP\u202f8 – The “Style Guide for Python Code”\n\nPEP\u202f8 (Python Enhancement Proposal\u202f8) is the de‑facto standard for writing readable, consistent Python code. It is not a strict compiler‑enforced rule, but a set of **conventions** that the Python community has agreed to follow because they make code easier to read, review, maintain, and collaborate on.\n\nBelow is a **complete, but still approachable, walkthrough** of what PEP\u202f8 covers, why the rules exist, and how you can apply them in day‑to‑day development.\n\n---  \n\n## 1. Why PEP\u202f8 Exists  \n\n| Goal | Reason |\n|------|--------|\n| **Readability** | Humans spend most of their time reading code, not writing it. Consistent formatting reduces the mental “parsing” overhead. |\n| **Collaboration** | A shared style means fewer nit‑picky code‑review comments and smoother merges across teams. |\n| **Tooling** | Many linters, formatters, and IDEs can automatically enforce the style, freeing developers from manual formatting. |\n| **Portability** | Code that follows a common style feels “native” to any Python developer, regardless of who wrote it. |\n\n---  \n\n## 2. The Core Principles  \n\n1. **Maximum line length – 79 characters** (72 for docstrings/comments).  \n2. **4‑space indentation** – no tabs.  \n3. **Consistent naming** (snake_case, PascalCase, etc.).  \n4. **One import per line** and imports ordered in sections.  \n5. **Whitespace used judiciously** (around operators, commas, etc.) but not excessive.  \n6. **Comments and docstrings should be clear, complete, and up‑to‑date**.  \n\n---  \n\n## 3. Detailed Guidelines (with examples)\n\n### 3.1 Indentation & Line Length  \n\n| Rule | Example |\n|------|---------|\n| Use **4 spaces** per indentation level. | ```python\\nif condition:\\n    do_something()\\n``` |\n| Limit **lines to 79 characters** (PEP\u202f8) – longer lines should be wrapped using parentheses, backslashes, or implicit continuation. | ```python\\n# Bad (96 chars)\\nresult = some_long_function_name(arg1, arg2, arg3, arg4, arg5, arg6, arg7, arg8)\\n\\n# Good (wrapped)\\nresult = some_long_function_name(\\n    arg1, arg2, arg3, arg4,\\n    arg5, arg6, arg7, arg8,\\n)\\n``` |\n| For docstrings/comments, aim for **72 characters**. | Same idea as above, but keep comment text ≤72. |\n\n### 3.2 Naming Conventions  \n\n| Symbol Type | Style | Example |\n|--------------|-------|---------|\n| **Modules** | **lowercase**, short, possibly underscores | `utils.py`, `data_loader.py` |\n| **Packages** | **lowercase**, no underscores (PEP\u202f8 recommends) | `myproject`, `analytics` |\n| **Classes** | **CapWords** (PascalCase) | `class DataProcessor:` |\n| **Exceptions** | **CapWords** ending in “Error” | `class ValidationError(Exception):` |\n| **Functions & Methods** | **snake_case** | `def calculate_average(values):` |\n| **Variables (global or local)** | **snake_case** | `total_sum = 0` |\n| **Constants** | **UPPERCASE_WITH_UNDERSCORES** | `MAX_RETRIES = 5` |\n| **Private names** (module‑internal) | leading underscore | `_cache = {}` |\n| * ...
